# %% [markdown]
# # N Queen Attack Detection

# %%
import random
def generate_positions(N):
    r = []
    c = []
    for i in range(1, N+1):    
        r.append(random.choice(range(1, N+1)))
        c.append(random.choice(range(1, N+1)))
        #check repetition of position
        print('Q{}: {},{}'.format(i,r[-1],c[-1]))
    return r,c

# %%
N = 4
row, col = generate_positions(N)
# Out:
# Q1: 3,1
# Q2: 4,4
# Q3: 4,4
# Q4: 1,3

# %%
# row attack
for i in range(0,N-1):
    for j in range(i+1,N):
        if row[i] == row[j]:
            print('Row attack: row:{} column:{} and {}'.format(row[i],col[i],col[j]))
# Out:
# row attack: row:4 column:4 and 4

# %%
#column attack
for x in range(0, N-1):
    for y in range(x+1, N):
        if col[x] == col[y]:
            print('Column attack: row:{} column:{} and {}'.format(row[x],col[y],col[y]))
# Out:
# Column attack: row:4 column:4 and 4

# %%
# diagonal atack

# %%
# implement a method to print a state is valid or not
# input row and col (two lists)
